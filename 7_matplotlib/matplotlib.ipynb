# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib grafica los datos en figuras (ventanas, widgets de Jupyter, etc.), cada una puede contener uno o más `Axes`, un área en donde los puntos pueden especificarse en coordenadas x-y y otras dimensiones. la forma más sencilla de crear una figura con axes es por mediodo de `pypplot.subplots`. `Axes.plot` se emplea par dibujar datos en los axes.

# %% [markdown]
# Los elementos de las gráficas de Matplotlib incluyen:
#
# | Elemento | Descripción |
# | --- | --- |
# | Figure | La figura completa. Incluye los axes (gráficas) y el canvas. |
# | Axes | Región en la figura con la gráfica |
# | Axis | Determinan los límites de las gráficas y generan ticks. |
# | Artist | Cualquier elemento visible en la gráfica. Se dibujan en el canvas. |

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4], [1,4,2,3])

# %% [markdown]
# El método `plot` permite graficar en el axes vigente.

# %%
plt.plot([1,2,3,4], [1,4,2,3])

# %% [markdown]
# Es posible crear una figura con más de una gráfica.

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2,2)

# %% [markdown]
# Todas las funciones de graficación de Matplotlib esperan `numpy.array` o `numpy.ma.masked_array` como entrada. Los objetos de datos de `pandas` deben convertirse antes de emplearse en Matplotlib. Los masked array son aquellos que tienen elementos faltantes o inválidos.

# %%
a = pd.DataFrame(np.random.rand(4, 5), columns=list("abcde"))
a_asarray = a.values
a_asarray
# Out:
# array([[0.02587374, 0.05172574, 0.73946492, 0.56238982, 0.56498262],
#        [0.77585825, 0.503733  , 0.95907003, 0.69450273, 0.16953762],
#        [0.42216394, 0.58043876, 0.20186251, 0.5554828 , 0.09942683],
#        [0.59668058, 0.69656643, 0.68472794, 0.66657858, 0.18750587]])

# %%
b = np.matrix([[1,2],[3,4]])
b_asarray = np.asarray(b)
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# # Las interfaces de Matplotlib
# | Interfaz | Comentarios |
# | --- | --- |
# | Orientada a objetos | Permite crear explísitamente las figuras y axes e invocar métodos en ellos. Recomendada para funciones o scritps que serán reusados en otro proyecto. |
# | pyplot | Crea gráficas automáticamente. Recomendada para graficación interactiva (p.e. en Jupyter). |

# %% [markdown]
# Interfaz orientada a objetos

# %%
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots()
ax.plot(x, x, label="linear")
ax.plot(x, x**2, label="quadratic")
ax.plot(x, x**3, label="cubic")
ax.set_xlabel("x label")
ax.set_ylabel("y label")
ax.set_title("Simple plot")
ax.legend()

# %% [markdown]
# Interfaz pyplot

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x, label="linear")
plt.plot(x, x**x, label="quadratic")
plt.plot(x, x**3, label="cubic")
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("Simple plot")
# Out:
# Text(0.5, 1.0, 'Simple plot')

# %% [markdown]
# También es posible integrar las gráficas de Matplotlib a otras GUIs. Actualmente se soporta PyQt/PySide, PyGObkect, Tkinter y wxPython.
# [Referemcoa de embeddings](https://matplotlib.org/stable/gallery/index.html#user-interfaces)

# %% [markdown]
# La siguiente función puede emplearse para crear múltiples gráficas con distintos parámetros.

# %%
def my_plotter(ax, data1, data2, param_dict):
    '''
    Helper function to make a graph
    
    Parameters
    ----------
    ax : Axes
        The axes to draw to
    
    data1 : array
        The x data
    
    data2 : array
        The y data

    param_dict : dict
        Dictionary of kwargs to pass to ax plot

    Returns
    -------
    out : list
        list of arists added
    '''

    out = ax.plot(data1, data2, **param_dict)
    return out

# %% [markdown]
# Ejemplo de uso de la función de graficación:

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)
fig, ax = plt.subplots(1, 1)
my_plotter(ax, data1, data2, {"marker": "x"})

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
my_plotter(ax1, data1, data2, {"marker": "x"})
my_plotter(ax2, data3, data4, {"marker": "o"})
